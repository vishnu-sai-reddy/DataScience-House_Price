# %%
import pandas as pd
import numpy as np
from IPython.display import HTML

import warnings
warnings.filterwarnings('ignore')
import datetime
house_price_df=pd.read_csv('1_housepriceCSV.csv')
house_price_df

#Converting int to object 
house_price_df[['MSSubClass','OverallQual','OverallCond','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr',
                'TotRmsAbvGrd','Fireplaces','GarageCars','MiscVal','MoSold']]=house_price_df[['MSSubClass','OverallQual','OverallCond','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd','Fireplaces','GarageCars','MiscVal','MoSold']].astype('object')
house_price_df[['MSSubClass','OverallQual','OverallCond','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr',
                'KitchenAbvGr','TotRmsAbvGrd','Fireplaces','GarageCars','MiscVal','MoSold']].dtypes

#feature engineering for year columns
current_year = datetime.datetime.now().year #get current year

YearBuilt = pd.DataFrame({"ActualYear":house_price_df['YearBuilt'],"CurrYear":current_year})
YearRemodAdd = pd.DataFrame({"ActualYear":house_price_df['YearRemodAdd'],"CurrYear":current_year})
GarageYrBlt = pd.DataFrame({"ActualYear":house_price_df['GarageYrBlt'],"CurrYear":current_year})
YrSold = pd.DataFrame({"ActualYear":house_price_df['YrSold'],"CurrYear":current_year})

house_price_df['YearBuilt'] = YearBuilt['CurrYear'] - YearBuilt['ActualYear'] 
house_price_df['YearRemodAdd'] = YearRemodAdd['CurrYear'] - YearRemodAdd['ActualYear'] 
house_price_df['GarageYrBlt'] = GarageYrBlt['CurrYear'] - GarageYrBlt['ActualYear'] 
house_price_df['YrSold'] = YrSold['CurrYear'] - YrSold['ActualYear'] 

# house_price_df['YrSold'].value_counts()
house_price_df['YearBuilt']=house_price_df['YearBuilt'].astype('object')
house_price_df['YearRemodAdd']=house_price_df['YearRemodAdd'].astype('object')
house_price_df['GarageYrBlt']=house_price_df['GarageYrBlt'].astype('object')
house_price_df['YrSold']=house_price_df['YrSold'].astype('object')

house_price_df[['YearBuilt','YearRemodAdd','GarageYrBlt','YrSold']]

# y = house_price_df['SalePrice']
# house_price_df.drop(columns='SalePrice',inplace=True)
# house_price_df
# house_price_df.shape

# y
# house_price_df[['MSSubClass','OverallQual','OverallCond','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr',
#                 'KitchenAbvGr','TotRmsAbvGrd','Fireplaces','GarageCars','MiscVal','MoSold']].dtypes

# # house_price_df.drop(columns=['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea'],inplace=True,axis=1)

# y=np.log(y)
# y

house_price_df['SalePrice'] = np.log(house_price_df['SalePrice'])
house_price_df['SalePrice']
# Out:
# 0       12.247694
# 1       12.109011
# 2       12.317167
# 3       11.849398
# 4       12.429216
#           ...
# 1455    12.072541
# 1456    12.254863
# 1457    12.493130
# 1458    11.864462
# 1459    11.901583
# Name: SalePrice, Length: 1460, dtype: float64

# %%
import pandas as pd
import numpy as np  #has all numerical functions
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# house_price_df
# house_price_dfcols = [col for col in house_price_df.columns if house_price_df[col].dtype == 'O']
# house_price_dfcols

sns.boxplot(x=house_price_df['MSSubClass'],y=house_price_df['SalePrice'],showmeans=True)
plt.figure(figsize=(20,10))
plt.show()

model =smf.ols(formula='SalePrice ~ MSSubClass', data=house_price_df) #(ordinary list squares)
results=model.fit()
results.summary()
# from scipy.stats import pearsonr    
# # house_price_df.corr()
# # c=np.corrcoef(house_price_df['LotArea'],house_price_df['SalePrice'])
# # c
# d=pearsonr(house_price_df['LotArea'],house_price_df['SalePrice'])
# d
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.330
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     50.87
# Date:                Thu, 09 Jan 2020   Prob (F-statistic):          5.10e-115
# Time:                        12:16:31   Log-Likelihood:                -438.88
# No. Observations:                1460   AIC:                             907.8
# Df Residuals:                    1445   BIC:                             987.0
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
house_price_df.isnull().sum()
missingvaluescount = pd.DataFrame({'columname':house_price_df.columns,
                           'missingvaluecount':house_price_df.isnull().sum(),
                           'missingvaluepercent':house_price_df.isnull().sum()/house_price_df.shape[0]*100})
missingvaluescount = missingvaluescount.sort_values(by='missingvaluepercent',ascending=False)
missingvaluescount
 
colstodrop = list(missingvaluescount[missingvaluescount['missingvaluepercent']>50]['columname'])
colstodrop

colstodrop1 = []

for col in house_price_df.columns:
    if house_price_df[col].nunique()==house_price_df.shape[0] or house_price_df[col].nunique()==1:
        colstodrop1.append(col)
        
colstodrop1

TotalColumns = colstodrop + colstodrop1
TotalColumns

house_price_df.drop(columns=TotalColumns,inplace=True)
house_price_df.shape

house_price_df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
# p_values_list

# new_df = pd.DataFrame({'column_name':house_price_df,
#                         'p-value':p_values_list})
# new_df

# new_df=new_df.sort_values(by='p-value',ascending=False)
# new_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-244-36fbeada85a4> in <module>
#       8 model =smf.ols(formula='MSSubClass ~ SalePrice', data=house_price_df) #(ordinary list squares)
#       9 results=model.fit()
# ---> 10 print(results.summary())
#      11
#      12
#
# E:\PYTHON_ANACONDA\lib\site-packages\statsmodels\regression\linear_model.py in summary(self, yname, xname, title, alpha)
#    2483
#    2484         rsquared_type = '' if self.k_constant else ' (uncentered)'
# -> 2485         top_right = [('R-squared' + rsquared_type + ':', ["%#8.3f" % self.rsquared]),
#    2486                      ('Adj. R-squared' + rsquared_type + ':', ["%#8.3f" % self.rsquared_adj]),
#    2487                      ('F-statistic:', ["%#8.4g" % self.fvalue]),
#
# E:\PYTHON_ANACONDA\lib\site-packages\statsmodels\tools\decorators.py in __get__(self, obj, type)
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(house_price_df,y,test_size=0.35,random_state=66)
for col in X_train.columns:
        if X_train[col].dtype==object:
            X_train[col]=X_train[col].fillna(X_train[col].mode()[0]).astype(object)
            X_test[col]=X_test[col].fillna(X_train[col].mode()[0]).astype(object)
        else:
            X_train[col]=X_train[col].fillna(X_train[col].mean())
            X_test[col]=X_test[col].fillna(X_train[col].mean())
X_train      
Y_train

# X_test
# Y_test
# Out:
# 610     12.653958
# 860     12.154516
# 17      11.407565
# 989     12.190959
# 313     12.834681
#           ...
# 1146    12.100712
# 51      11.648330
# 631     12.252479
# 828     12.128111
# 1044    12.535376
# Name: SalePrice, Length: 949, dtype: float64

# %%
X_train_int_float = [i for i in X_train.columns if X_train[i].dtype == 'int64' or X_train[i].dtype == 'float64']
X_train_obj = [i for i in X_train.columns if X_train[i].dtype == object ]

len(X_train_obj + X_train_int_float)
# Out:
# 75

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\PYTHON_ANACONDA\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'VIF FACTOR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-180-f5fde4860615> in <module>
#       4 vif=pd.DataFrame()
#       5
# ...

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoderExt()

for col in X_train_obj:
        le.fit(X_train[col])
        X_train[col]=le.transform(X_train[col])
        X_test[col]=le.transform(X_test[col])
X_train
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 610           15         3    70.562821    11050       1         3
# 860           15         3    55.000000     7642       1         3
# 17            15         3    72.000000    10791       1         3
# 989           15         1    65.000000     8125       1         3
# 313           15         3   150.000000   215245       1         2
# ...          ...       ...          ...      ...     ...       ...
# 1146          15         3    70.562821    11200       1         3
# 51            15         4    52.000000     6240       1         3
# 631           15         3    34.000000     4590       1         3
# 828           15         3    70.562821    28698       1         1
# 1044          15         3    80.000000     9600       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  OpenPorchSF  \
# 610             3          0          4          0  ...          142
# ...

# %%
#preproceesing
from sklearn.preprocessing import MinMaxScaler

min_max=MinMaxScaler()

for col in X_train_int_float:
        X_train[col]=min_max.fit_transform(X_train[[col]])#fit_transform for Xtrain
        X_test[col]=min_max.transform(X_test[[col]])#transform for Xtrain


X_train
# Y_test
# Out:
#       MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  \
# 610           15         3     0.169736  0.045572       1         3
# 860           15         3     0.116438  0.029643       1         3
# 17            15         3     0.174658  0.044362       1         3
# 989           15         1     0.150685  0.031901       1         3
# 313           15         3     0.441781  1.000000       1         2
# ...          ...       ...          ...       ...     ...       ...
# 1146          15         3     0.169736  0.046274       1         3
# 51            15         4     0.106164  0.023090       1         3
# 631           15         3     0.044521  0.015378       1         3
# 828           15         3     0.169736  0.128061       1         1
# 1044          15         3     0.202055  0.038795       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  OpenPorchSF  \
# 610             3          0          4          0  ...     0.259598
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from IPython.display import HTML
vif=pd.DataFrame()

vif["VIF Factor"]=[variance_inflation_factor(X_train.values,i) for i in range(X_train.shape[1])]

vif['Column name']=X_train.columns

vif
HTML(vif.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>VIF Factor</th>
#       <th>Column name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.000000</td>
#       <td>MSSubClass</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.315208</td>
#       <td>MSZoning</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.767776</td>
#       <td>LotFrontage</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.621411</td>
#       <td>LotArea</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.238206</td>
#       <td>Street</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.266340</td>
#       <td>LotShape</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1.316313</td>
#       <td>LandContour</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1.109812</td>
#       <td>Utilities</td>
#     </tr>
#     <tr>
#       <th>8</th>
# ...

# %%
X_train.drop(columns=['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea'],inplace=True,axis=1)
X_test.drop(columns=['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea'],inplace=True,axis=1)

# %%
from sklearn.linear_model import LinearRegression

linearreg = LinearRegression()

linearreg.fit(X_train,Y_train)
y_pred = linearreg.predict(X_test)
# y_pred = np.log(y_pred)
# Y_test = np.log(Y_test)
comp_df = pd.DataFrame({'Actual_values': np.exp(Y_test),'Predicted':np.exp(y_pred)})
# comp_df = pd.DataFrame({'Actual_values':Y_test,'Predicted':y_pred})
comp_df
np.exp(Y_test)
# Out:
# 634     144000.0
# 1354    235000.0
# 867     129000.0
# 55      180500.0
# 160     162500.0
#           ...
# 351     190000.0
# 62      202500.0
# 91       98600.0
# 1212    113000.0
# 165     127500.0
# Name: SalePrice, Length: 511, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test,y_pred)
# Out:
# 0.04337942436290236

# %%
from sklearn.metrics import r2_score

r2_score(Y_test,y_pred)

#linearreg.coef_
# Out:
# 0.7226441008372837
